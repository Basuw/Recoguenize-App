# %%
import numpy as np
from scipy import signal
from scipy.io.wavfile import read
import requests


# Création de la constellation des pics significatifs
# audio_data correspond au data du fichier .wav
# fs correspond à la fréquence d'échantillonage

def create_peak_constellation(audio_data, Fs):
    num_peaks = 15

    # On applique une STFT sur l'audio étudié

    frequencies, times, stft = signal.stft(
        x = audio_data, fs = Fs, nperseg= 512, nfft = 512, return_onesided=True, noverlap= 0,
    )

    constellation_map = []

    for time_index, window in enumerate(stft.T):
        # On convertit le spectre en valeur réel
        spectrum = abs(window)
        
        # On identifie les pics les plus importants 
        peaks, props = signal.find_peaks(spectrum, prominence=0, distance=21)

        n_peaks = min(num_peaks, len(peaks))

        largest_peaks = np.argpartition(props["prominences"], -n_peaks)[-n_peaks:]
        for peak in peaks[largest_peaks]:
            frequency = frequencies[peak]
            time_in_seconds = times[time_index]
            constellation_map.append([time_in_seconds, frequency])
    
    return constellation_map

def create_data(constellation_map):
    upper_frequency = 23000
    frequency_bits = 10
    data = []

    # On parcourt la constellation pour créer les hashs
    for idx, (time, freq) in enumerate(constellation_map[:-1]):

        other_freq = constellation_map[idx + 1][1]

        time_diff = constellation_map[idx + 1][0] - time
        freq_diff = abs(other_freq - freq)

        if time_diff <= 0 and freq_diff <= 3000 :
            continue

        freq_binned = freq / upper_frequency * (2 ** frequency_bits)
        other_freq_binned = other_freq / upper_frequency * (2 ** frequency_bits)

        invariant = freq_binned/other_freq_binned

        data.append({
            "invariantComponent": invariant,
            "variantComponent": time_diff,
            "localisation": time,
            "songID": 1
        })

    return data

def send_data_in_batches(data, url,batch_size=50):
    all_responses = []
    headers = {
    'Content-Type': 'application/json'
    }

    for i in range(0, len(data), batch_size):
        batch = data[i:i + batch_size]
        response = requests.post(url, json=batch, headers=headers)

        if response.status_code == 200:
            print(f'Batch {i//batch_size + 1} envoyé avec succès')
            print(f'Réponse du serveur : {response.text}')

            all_responses.append(response.json())
        else:
            print(f'Erreur lors de l\'envoi du batch {i//batch_size + 1}, statut: {response.status_code}')
            print(f'Réponse du serveur : {response.text}')
    
    return all_responses

def create_histograms(all_responses):
    # Pour chaque reponse (indice array)
        # Pour chaque clé de map
            # Pour chaque pair de finger print en DB et Enregistré, faire la différence de "localisation"
                #  Ajouter 1 à la valeur de la "localisation" de l'histogramme associé à la clé de la map
    # Retourner la liste qui contient le nombre d'occurence de la différence de localisation par histogramme

    # Initialisation d'un dictionnaire pour stocker les histogrammes des différences de localisation
    histograms = {}

    for response in all_responses:
        # Pour chaque clé dans la réponse (songID)
        for song_id, matches in response.items():
            if song_id not in histograms:
                histograms[song_id] = {}

            # Pour chaque paire de fingerprints dans les correspondances
            for match in matches:
                song_fp = match['songFingerprint']
                db_fp = match['databaseFingerprint']

                # Calcul de la différence de localisation
                local_diff = song_fp['localisation'] - db_fp['localisation']

                # Mise à jour de l'histogramme pour ce song_id
                if local_diff not in histograms[song_id]:
                    histograms[song_id][local_diff] = 0

                histograms[song_id][local_diff] += 1

    return histograms

def find_best_match(histograms):
    # Pour chaque histogramme
        # Pour chaque clé de l'histogramme
            # Si la valeur de la clé est supérieure à 10
                # Ajouter la clé à la liste des candidats
    # Retourner le candidat avec la valeur la plus élevée

    best_match = None
    best_score = 0
    count_offset = 10

    for song_id, histogram in histograms.items():
        for local_diff, count in histogram.items():
            if count > count_offset:
                if count > best_score:
                    best_score = count
                    best_match = song_id

    return best_match

def get_song_info(song_id):
    headers = {
    'Content-Type': 'application/json'
    }
    url = 'http://51.120.246.62:8080/song/'
    response = requests.get(url=url + str(song_id),headers=headers)

    if response.status_code == 202:
        return response.json()
    else:
        return None

def start_process(choice = 0):
    # Si choice = 0, on fonctionne en comparaison
    Fs, data = read("../Documents/gitano.wav")
    constellation = create_peak_constellation(data,Fs)
    data = create_data(constellation)
    
   
    if choice == 0:
        url = 'http://51.120.246.62:8080/fingerprint/compare/'
    else:
        url = 'http://51.120.246.62:8080/fingerprint/'
    
    all_responses = send_data_in_batches(data,url)
    
    if choice == 0:
        histograms = create_histograms(all_responses)
        best_match = find_best_match(histograms)
        song_info = get_song_info(best_match)

    return song_info
    #return best_match


song = start_process()
print(song)
# Out:
# /var/folders/9y/fbqptfm91cv58jfzq06lhlk40000gn/T/ipykernel_51437/2984664274.py:156: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   Fs, data = read("../Documents/gitano.wav")
# Batch 1 envoyé avec succès
# Réponse du serveur : {"1":[{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.011609977324263054,"localisation":0.5340589569160997}},{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.011609977324263054,"localisation":0.7430385487528345}},{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.011609977324263054,"localisation":0.8243083900226758}},{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.011609977324263054,"localisation":0.5340589569160997}},{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.011609977324263054,"localisation":0.7430385487528345}},{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.011609977324263054,"localisation":0.8243083900226758}}],"2":[{"songFingerprint":{"invariantComponent":0.003968253968253968,"variantComponent":0.01160997732426304,"localisation":0.08126984126984127},"databaseFingerprint":{"invariantComponent":0.003968253968253968,"variantComponent":0.011609977324263165,"localisation":0.9984580498866212}}],"3":[{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585}},{"songFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.011609977324263037,"localisation":0.023219954648526078},"databaseFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.011609977324263054,"localisation":0.3250793650793651}},{"songFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.011609977324263037,"localisation":0.023219954648526078},"databaseFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.011609977324263054,"localisation":0.5804988662131519}}],"4":[{"songFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.011609977324263037,"localisation":0.023219954648526078},"databaseFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.01160997732426304,"localisation":0.034829931972789115}}],"5":[{"songFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037},"databaseFingerprint":{"invariantComponent":0.019841269841269844,"variantComponent":0.01160997732426304,"localisation":0.011609977324263037}},{"songFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.011609977324263037,"localisation":0.023219954648526078},"databaseFingerprint":{"invariantComponent":0.00851063829787234,"variantComponent":0.011609977324263037,"localisation":0.023219954648526078}},{"songFingerprint":{"invariantComponent":0.005076142131979696,"variantComponent":0.01160997732426304,"localisation":0.034829931972789115},"databaseFingerprint":{"invariantComponent":0.005076142131979696,"variantComponent":0.01160997732426304,"localisation":0.034829931972789115}},{"songFingerprint":{"invariantComponent":0. ...
# Batch 2 envoyé avec succès
# Réponse du serveur : {"4":[{"songFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263027,"localisation":0.19736961451247165},"databaseFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263027,"localisation":0.18575963718820862}},{"songFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263027,"localisation":0.19736961451247165},"databaseFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263054,"localisation":0.8359183673469388}}],"5":[{"songFingerprint":{"invariantComponent":1.0352422907488987,"variantComponent":0.011609977324263027,"localisation":0.13931972789115646},"databaseFingerprint":{"invariantComponent":1.0352422907488987,"variantComponent":0.011609977324263027,"localisation":0.13931972789115646}},{"songFingerprint":{"invariantComponent":0.9725490196078432,"variantComponent":0.011609977324263054,"localisation":0.15092970521541949},"databaseFingerprint":{"invariantComponent":0.9725490196078432,"variantComponent":0.011609977324263054,"localisation":0.15092970521541949}},{"songFingerprint":{"invariantComponent":0.013333333333333332,"variantComponent":0.011609977324263027,"localisation":0.16253968253968254},"databaseFingerprint":{"invariantComponent":0.013333333333333332,"variantComponent":0.011609977324263027,"localisation":0.16253968253968254}},{"songFingerprint":{"invariantComponent":1.3085106382978724,"variantComponent":0.011609977324263054,"localisation":0.17414965986394557},"databaseFingerprint":{"invariantComponent":1.3085106382978724,"variantComponent":0.011609977324263054,"localisation":0.17414965986394557}},{"songFingerprint":{"invariantComponent":1.0125,"variantComponent":0.011609977324263027,"localisation":0.18575963718820862},"databaseFingerprint":{"invariantComponent":1.0125,"variantComponent":0.011609977324263027,"localisation":0.18575963718820862}},{"songFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263027,"localisation":0.19736961451247165},"databaseFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263027,"localisation":0.19736961451247165}},{"songFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263027,"localisation":0.19736961451247165},"databaseFingerprint":{"invariantComponent":0.012195121951219511,"variantComponent":0.011609977324263054,"localisation":0.3250793650793651}},{"songFingerprint":{"invariantComponent":0.005347593582887701,"variantComponent":0.011609977324263054,"localisation":0.20897959183673467},"databaseFingerprint":{"invariantComponent":0.005347593582887701,"variantComponent":0.011609977324263054,"localisation":0.20897959183673467}},{"songFingerprint":{"invariantComponent":1.0119521912350598,"variantComponent":0.011609977324263027,"localisation":0.22058956916099773},"databaseFingerprint":{"invariantComponent":1.0119521912350598,"variantComponent":0.011609977324263027,"localisation":0.22058956916099773}},{"songFingerprint":{"invariantComponent":0.015306122448979591,"variantComponent":0.011609977324263054,"localisation":0.23219954648526075},"databaseFingerprint":{"invariantComponent":0.015306122448979591,"variantComponent":0.011609977324263054,"localisation":0.23219954648526075}},{"songFingerprint":{"invariantComponent":1.0204081632653061,"variantComponent":0.011609977324263054,"localisation":0.2438095238095238},"databaseFingerprint":{"invariantComponent":1.0204081632653061,"variantComponent":0.011609977324263054,"localisation":0.2438095238095238}}]}
# Batch 3 envoyé avec succès
# Réponse du serveur : {"1":[{"songFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324263054,"localisation":0.26702947845804986},"databaseFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324263027,"localisation":0.18575963718820862}},{"songFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324263054,"localisation":0.26702947845804986},"databaseFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324263027,"localisation":0.18575963718820862}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324262999,"localisation":0.37151927437641724}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324262999,"localisation":0.37151927437641724}}],"2":[{"songFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324263054,"localisation":0.26702947845804986},"databaseFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324263047,"localisation":0.058049886621315196}},{"songFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324263054,"localisation":0.26702947845804986},"databaseFingerprint":{"invariantComponent":0.01195219123505976,"variantComponent":0.011609977324262943,"localisation":0.603718820861678}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.01160997732426304,"localisation":0.09287981859410431}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.01160997732426304,"localisation":0.10448979591836735}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.26702947845804986}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.44117913832199546}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.6733786848072563}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.8359183673469388}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324262943,"localisation":0.9287981859410431}},{"songFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542},"databaseFingerprint":{"invariantComponent":0.011764705882352941,"variantComponent":0.011609977324263054,"localisation":0.9520181405895691}}],"3":[{"songFingerprint":{"invariantComponent":0.01195219123505976,"vari ...
# Batch 4 envoyé avec succès
# Réponse du serveur : {"1":[{"songFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585},"databaseFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262943,"localisation":0.6849886621315193}},{"songFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585},"databaseFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262943,"localisation":0.6849886621315193}}],"3":[{"songFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585},"databaseFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324263027,"localisation":0.16253968253968254}},{"songFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585},"databaseFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324263054,"localisation":0.3599092970521542}},{"songFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585},"databaseFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324263054,"localisation":0.592108843537415}}],"4":[{"songFingerprint":{"invariantComponent":0.004081632653061225,"variantComponent":0.011609977324262999,"localisation":0.4179591836734694},"databaseFingerprint":{"invariantComponent":0.004081632653061225,"variantComponent":0.011609977324263054,"localisation":0.34829931972789113}}],"5":[{"songFingerprint":{"invariantComponent":1.0040650406504064,"variantComponent":0.011609977324263054,"localisation":0.38312925170068024},"databaseFingerprint":{"invariantComponent":1.0040650406504064,"variantComponent":0.011609977324263054,"localisation":0.38312925170068024}},{"songFingerprint":{"invariantComponent":0.01785714285714286,"variantComponent":0.011609977324263054,"localisation":0.3947392290249433},"databaseFingerprint":{"invariantComponent":0.01785714285714286,"variantComponent":0.011609977324263054,"localisation":0.3947392290249433}},{"songFingerprint":{"invariantComponent":1.0244897959183674,"variantComponent":0.011609977324263054,"localisation":0.40634920634920635},"databaseFingerprint":{"invariantComponent":1.0244897959183674,"variantComponent":0.011609977324263054,"localisation":0.40634920634920635}},{"songFingerprint":{"invariantComponent":0.004081632653061225,"variantComponent":0.011609977324262999,"localisation":0.4179591836734694},"databaseFingerprint":{"invariantComponent":0.004081632653061225,"variantComponent":0.011609977324262999,"localisation":0.4179591836734694}},{"songFingerprint":{"invariantComponent":0.03225806451612903,"variantComponent":0.011609977324263054,"localisation":0.4295691609977324},"databaseFingerprint":{"invariantComponent":0.03225806451612903,"variantComponent":0.011609977324263054,"localisation":0.4295691609977324}},{"songFingerprint":{"invariantComponent":0.9568627450980393,"variantComponent":0.011609977324263054,"localisation":0.44117913832199546},"databaseFingerprint":{"invariantComponent":0.9568627450980393,"variantComponent":0.011609977324263054,"localisation":0.44117913832199546}},{"songFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585},"databaseFingerprint":{"invariantComponent":0.008333333333333333,"variantComponent":0.011609977324262999,"localisation":0.4527891156462585}},{"songFingerprint":{"invariantComponent":0.027397260273972605,"variantComponent":0.011609977324263054,"localisation":0.4643990929705215},"databaseFingerprint":{"invariantComponent":0.027397260273972605,"variantComponent":0.011609977324263054,"localisation":0.4643990929705215}},{"songFingerprint":{"invariantComponent":1.0704845814977972,"variantComp ...
# Batch 5 envoyé avec succès
# Réponse du serveur : {"1":[{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324262943,"localisation":0.5224489795918368},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263027,"localisation":0.06965986394557824}},{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324262943,"localisation":0.5224489795918368},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263027,"localisation":0.06965986394557824}}],"3":[{"songFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324263054,"localisation":0.5804988662131519},"databaseFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324263054,"localisation":0.893968253968254}},{"songFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324262943,"localisation":0.603718820861678},"databaseFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324263054,"localisation":0.893968253968254}}],"5":[{"songFingerprint":{"invariantComponent":0.9480000000000001,"variantComponent":0.011609977324263054,"localisation":0.5108390022675737},"databaseFingerprint":{"invariantComponent":0.9480000000000001,"variantComponent":0.011609977324263054,"localisation":0.5108390022675737}},{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324262943,"localisation":0.5224489795918368},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324262943,"localisation":0.5224489795918368}},{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324262943,"localisation":0.5224489795918368},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263054,"localisation":0.8126984126984127}},{"songFingerprint":{"invariantComponent":1.090909090909091,"variantComponent":0.011609977324263054,"localisation":0.5340589569160997},"databaseFingerprint":{"invariantComponent":1.090909090909091,"variantComponent":0.011609977324263054,"localisation":0.5340589569160997}},{"songFingerprint":{"invariantComponent":1.2401960784313726,"variantComponent":0.011609977324263054,"localisation":0.5456689342403628},"databaseFingerprint":{"invariantComponent":1.2401960784313726,"variantComponent":0.011609977324263054,"localisation":0.5456689342403628}},{"songFingerprint":{"invariantComponent":1.016,"variantComponent":0.011609977324263054,"localisation":0.5572789115646258},"databaseFingerprint":{"invariantComponent":1.016,"variantComponent":0.011609977324263054,"localisation":0.5572789115646258}},{"songFingerprint":{"invariantComponent":0.01568627450980392,"variantComponent":0.011609977324263054,"localisation":0.5688888888888889},"databaseFingerprint":{"invariantComponent":0.01568627450980392,"variantComponent":0.011609977324263054,"localisation":0.5688888888888889}},{"songFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324263054,"localisation":0.5804988662131519},"databaseFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324263054,"localisation":0.5804988662131519}},{"songFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324263054,"localisation":0.5804988662131519},"databaseFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324262943,"localisation":0.603718820861678}},{"songFingerprint":{"invariantComponent":0.08298755186721991,"variantComponent":0.011609977324263054,"localisation":0.592108843537415},"databaseFingerprint":{"invariantComponent":0.08298755186721991,"variantComponent":0.011609977324263054,"localisation":0.592108843537415}},{"songFingerprint":{"invariantComponent":0.05555555555555555,"variantComponent":0.011609977324262943,"localisation":0.60371882086 ...
# Batch 6 envoyé avec succès
# Réponse du serveur : {"1":[{"songFingerprint":{"invariantComponent":0.02469135802469136,"variantComponent":0.011609977324263054,"localisation":0.7314285714285714},"databaseFingerprint":{"invariantComponent":0.02469135802469136,"variantComponent":0.011609977324262999,"localisation":0.29024943310657597}},{"songFingerprint":{"invariantComponent":0.02469135802469136,"variantComponent":0.011609977324263054,"localisation":0.7314285714285714},"databaseFingerprint":{"invariantComponent":0.02469135802469136,"variantComponent":0.011609977324262999,"localisation":0.29024943310657597}}],"2":[{"songFingerprint":{"invariantComponent":1.0,"variantComponent":0.011609977324263054,"localisation":0.7198185941043084},"databaseFingerprint":{"invariantComponent":1.0,"variantComponent":0.011609977324263054,"localisation":0.7894784580498866}}],"3":[{"songFingerprint":{"invariantComponent":1.0,"variantComponent":0.011609977324263054,"localisation":0.7198185941043084},"databaseFingerprint":{"invariantComponent":1.0,"variantComponent":0.011609977324262999,"localisation":0.4179591836734694}}],"5":[{"songFingerprint":{"invariantComponent":0.13020833333333331,"variantComponent":0.011609977324263054,"localisation":0.6501587301587302},"databaseFingerprint":{"invariantComponent":0.13020833333333331,"variantComponent":0.011609977324263054,"localisation":0.6501587301587302}},{"songFingerprint":{"invariantComponent":0.9959677419354838,"variantComponent":0.011609977324263054,"localisation":0.6617687074829932},"databaseFingerprint":{"invariantComponent":0.9959677419354838,"variantComponent":0.011609977324263054,"localisation":0.6617687074829932}},{"songFingerprint":{"invariantComponent":0.010256410256410256,"variantComponent":0.011609977324263054,"localisation":0.6733786848072563},"databaseFingerprint":{"invariantComponent":0.010256410256410256,"variantComponent":0.011609977324263054,"localisation":0.6733786848072563}},{"songFingerprint":{"invariantComponent":0.010256410256410256,"variantComponent":0.011609977324263054,"localisation":0.6733786848072563},"databaseFingerprint":{"invariantComponent":0.010256410256410256,"variantComponent":0.011609977324263165,"localisation":0.9984580498866212}},{"songFingerprint":{"invariantComponent":0.9176470588235295,"variantComponent":0.011609977324262943,"localisation":0.6849886621315193},"databaseFingerprint":{"invariantComponent":0.9176470588235295,"variantComponent":0.011609977324262943,"localisation":0.6849886621315193}},{"songFingerprint":{"invariantComponent":0.004166666666666667,"variantComponent":0.011609977324263054,"localisation":0.6965986394557823},"databaseFingerprint":{"invariantComponent":0.004166666666666667,"variantComponent":0.011609977324263054,"localisation":0.6965986394557823}},{"songFingerprint":{"invariantComponent":0.021276595744680854,"variantComponent":0.011609977324263054,"localisation":0.7082086167800453},"databaseFingerprint":{"invariantComponent":0.021276595744680854,"variantComponent":0.011609977324263054,"localisation":0.7082086167800453}},{"songFingerprint":{"invariantComponent":1.0,"variantComponent":0.011609977324263054,"localisation":0.7198185941043084},"databaseFingerprint":{"invariantComponent":1.0,"variantComponent":0.011609977324263054,"localisation":0.7198185941043084}},{"songFingerprint":{"invariantComponent":0.02469135802469136,"variantComponent":0.011609977324263054,"localisation":0.7314285714285714},"databaseFingerprint":{"invariantComponent":0.02469135802469136,"variantComponent":0.011609977324263054,"localisation":0.7314285714285714}},{"songFingerprint":{"invariantComponent":0.015463917525773195,"variantComponent":0.011609977324263054,"localisation":0.7430385487528345},"databaseFingerprint":{"invariantComponent":0.015463917525773195,"variantComponent":0.011609977324263054,"localisation":0.7430385487528345}},{"songFingerprint":{"invariantComponent":0.9873949579831933,"variantComponent":0.011609977324263054,"localisation":0.7546485260770975},"databaseFingerprint":{"invariantComponent": ...
# Batch 7 envoyé avec succès
# Réponse du serveur : {"1":[{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263054,"localisation":0.8126984126984127},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263027,"localisation":0.06965986394557824}},{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263054,"localisation":0.8126984126984127},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263027,"localisation":0.06965986394557824}}],"2":[{"songFingerprint":{"invariantComponent":0.008264462809917356,"variantComponent":0.011609977324263054,"localisation":0.8707482993197279},"databaseFingerprint":{"invariantComponent":0.008264462809917356,"variantComponent":0.011609977324263027,"localisation":0.13931972789115646}},{"songFingerprint":{"invariantComponent":0.009216589861751152,"variantComponent":0.011609977324263054,"localisation":0.893968253968254},"databaseFingerprint":{"invariantComponent":0.009216589861751152,"variantComponent":0.011609977324263054,"localisation":0.7778684807256235}}],"3":[{"songFingerprint":{"invariantComponent":0.008264462809917356,"variantComponent":0.011609977324263054,"localisation":0.8707482993197279},"databaseFingerprint":{"invariantComponent":0.008264462809917356,"variantComponent":0.011609977324263054,"localisation":0.6965986394557823}}],"4":[{"songFingerprint":{"invariantComponent":0.008264462809917356,"variantComponent":0.011609977324263054,"localisation":0.8707482993197279},"databaseFingerprint":{"invariantComponent":0.008264462809917356,"variantComponent":0.011609977324263027,"localisation":0.22058956916099773}}],"5":[{"songFingerprint":{"invariantComponent":1.2450980392156863,"variantComponent":0.011609977324263054,"localisation":0.7778684807256235},"databaseFingerprint":{"invariantComponent":1.2450980392156863,"variantComponent":0.011609977324263054,"localisation":0.7778684807256235}},{"songFingerprint":{"invariantComponent":1.1495327102803738,"variantComponent":0.011609977324263054,"localisation":0.7894784580498866},"databaseFingerprint":{"invariantComponent":1.1495327102803738,"variantComponent":0.011609977324263054,"localisation":0.7894784580498866}},{"songFingerprint":{"invariantComponent":1.012,"variantComponent":0.011609977324263054,"localisation":0.8010884353741496},"databaseFingerprint":{"invariantComponent":1.012,"variantComponent":0.011609977324263054,"localisation":0.8010884353741496}},{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263054,"localisation":0.8126984126984127},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324262943,"localisation":0.5224489795918368}},{"songFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263054,"localisation":0.8126984126984127},"databaseFingerprint":{"invariantComponent":0.014851485148514853,"variantComponent":0.011609977324263054,"localisation":0.8126984126984127}},{"songFingerprint":{"invariantComponent":1.1132075471698115,"variantComponent":0.011609977324263054,"localisation":0.8243083900226758},"databaseFingerprint":{"invariantComponent":1.1132075471698115,"variantComponent":0.011609977324263054,"localisation":0.8243083900226758}},{"songFingerprint":{"invariantComponent":0.9958677685950413,"variantComponent":0.011609977324263054,"localisation":0.8359183673469388},"databaseFingerprint":{"invariantComponent":0.9958677685950413,"variantComponent":0.011609977324263054,"localisation":0.8359183673469388}},{"songFingerprint":{"invariantComponent":0.008968609865470852,"variantComponent":0.011609977324262943,"localisation":0.8475283446712019},"databaseFingerprint":{"invariantComponent":0.008968609865470852,"variantComponent":0.011609977324262943,"localisation":0.8475283446712019}},{"songFingerprint":{"invariantComponent":0.9724409448818897,"variantComponent":0.011609977324263054, ...
# Batch 8 envoyé avec succès
# Réponse du serveur : {"1":[{"songFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262943,"localisation":0.9868480725623583},"databaseFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262999,"localisation":0.4179591836734694}},{"songFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262943,"localisation":0.9868480725623583},"databaseFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262999,"localisation":0.4179591836734694}}],"2":[{"songFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262943,"localisation":0.9868480725623583},"databaseFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324263054,"localisation":0.592108843537415}}],"4":[{"songFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262943,"localisation":0.9868480725623583},"databaseFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324263027,"localisation":0.19736961451247165}},{"songFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262943,"localisation":0.9868480725623583},"databaseFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324263054,"localisation":0.2786394557823129}}],"5":[{"songFingerprint":{"invariantComponent":0.9448818897637795,"variantComponent":0.011609977324263054,"localisation":0.905578231292517},"databaseFingerprint":{"invariantComponent":0.9448818897637795,"variantComponent":0.011609977324263054,"localisation":0.905578231292517}},{"songFingerprint":{"invariantComponent":0.013888888888888888,"variantComponent":0.011609977324263054,"localisation":0.9171882086167801},"databaseFingerprint":{"invariantComponent":0.013888888888888888,"variantComponent":0.011609977324263054,"localisation":0.9171882086167801}},{"songFingerprint":{"invariantComponent":1.125,"variantComponent":0.011609977324262943,"localisation":0.9287981859410431},"databaseFingerprint":{"invariantComponent":1.125,"variantComponent":0.011609977324262943,"localisation":0.9287981859410431}},{"songFingerprint":{"invariantComponent":1.195,"variantComponent":0.011609977324263054,"localisation":0.9404081632653061},"databaseFingerprint":{"invariantComponent":1.195,"variantComponent":0.011609977324263054,"localisation":0.9404081632653061}},{"songFingerprint":{"invariantComponent":1.2105263157894737,"variantComponent":0.011609977324263054,"localisation":0.9520181405895691},"databaseFingerprint":{"invariantComponent":1.2105263157894737,"variantComponent":0.011609977324263054,"localisation":0.9520181405895691}},{"songFingerprint":{"invariantComponent":0.9837398373983739,"variantComponent":0.011609977324263054,"localisation":0.9636281179138322},"databaseFingerprint":{"invariantComponent":0.9837398373983739,"variantComponent":0.011609977324263054,"localisation":0.9636281179138322}},{"songFingerprint":{"invariantComponent":0.03333333333333333,"variantComponent":0.011609977324263054,"localisation":0.9752380952380952},"databaseFingerprint":{"invariantComponent":0.03333333333333333,"variantComponent":0.011609977324263054,"localisation":0.9752380952380952}},{"songFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262943,"localisation":0.9868480725623583},"databaseFingerprint":{"invariantComponent":0.012396694214876033,"variantComponent":0.011609977324262943,"localisation":0.9868480725623583}},{"songFingerprint":{"invariantComponent":0.010256410256410256,"variantComponent":0.011609977324263165,"localisation":0.9984580498866212},"databaseFingerprint":{"invariantComponent":0.010256410256410256,"variantComponent":0.011609977324263054,"localisation":0.6733786848072563}},{"songFingerprint":{"invariantComponent":0.010256410256410256,"variantComponent":0.011609977324263165,"localisation":0.9984580498866212},"d ...
# Batch 9 envoyé avec succès
# Réponse du serveur : {"2":[{"songFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":1.0448979591836736},"databaseFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":0.4295691609977324}},{"songFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":1.0448979591836736},"databaseFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":0.7430385487528345}},{"songFingerprint":{"invariantComponent":0.00816326530612245,"variantComponent":0.011609977324263054,"localisation":1.0565079365079366},"databaseFingerprint":{"invariantComponent":0.00816326530612245,"variantComponent":0.011609977324263054,"localisation":0.6617687074829932}}],"3":[{"songFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":1.0448979591836736},"databaseFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":0.8591383219954648}}],"5":[{"songFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":1.0448979591836736},"databaseFingerprint":{"invariantComponent":0.012145748987854251,"variantComponent":0.011609977324263054,"localisation":1.0448979591836736}},{"songFingerprint":{"invariantComponent":0.00816326530612245,"variantComponent":0.011609977324263054,"localisation":1.0565079365079366},"databaseFingerprint":{"invariantComponent":0.00816326530612245,"variantComponent":0.011609977324263054,"localisation":1.0565079365079366}}]}
# {'id': 5, 'title': 'Gitano', 'duration': '00:03:45', 'type': 'pop urbaine', 'description': 'Musique francaise', 'certification': 'aucune', 'artistsSong': [], 'albumsSong': []}
